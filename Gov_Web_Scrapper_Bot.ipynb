# %% [markdown]
# ## Preprocessing

# %% [markdown]
# Cell 1 — install dependencies

# %%
# Colab cell 1 - install libs
# !pip install -q requests beautifulsoup4 sentence_transformers scikit-learn pdfplumber Flask pyngrok apscheduler tqdm nltk
# (optional) if you want Playwright for JS-rendered pages:
# !pip install -q playwright
# !playwright install --with-deps

# %% [markdown]
# Cell 2 — imports & helper utilities

# %%
# Colab cell 2 - imports and helpers
import os, csv, json, time, hashlib, sqlite3
from urllib.parse import urljoin, urlparse
import requests
from bs4 import BeautifulSoup
from tqdm.notebook import tqdm

# small helper
def ensure_dir(path):
    if not os.path.exists(path):
        os.makedirs(path)

ensure_dir("raw_html")
ensure_dir("pdfs")
ensure_dir("extracted_text")
ensure_dir("wiki_pages")

# %%
# NEW, CONSOLIDATED HELPER FUNCTIONS CELL (Place this after Cell 2)

# --- Core Helper Functions ---

import re, nltk
from nltk.tokenize import sent_tokenize
import pdfplumber

# Download NLTK data once
nltk.download('punkt')
nltk.download('punkt_tab') # Added download for punkt_tab

# --- Main Crawler Function (from original Cell 5) ---
def crawl_with_heuristics(seed_url, max_depth=3, max_pages=200):
    parsed = urlparse(seed_url)
    base_domain = parsed.netloc
    visited = set()
    to_visit = [(seed_url, 0)]
    scheme_urls = set()

    # Keywords to identify relevant pages
    include_keywords = ["scheme", "yojana", "benefit", "notification", "gr",
                        "department", "program", "service", "guidelines", "circular"]
    # Patterns to exclude irrelevant links
    exclude_patterns = ["login", "logout", "print", "signin", "signup", "register",
                        "/admin", "/dashboard", "?session", "reset", "#", "?lang", ".jpg", ".png"]

    # Use a shared session for efficiency
    with requests.Session() as session:
        session.headers.update({
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
        })

        pbar = tqdm(total=max_pages, desc=f"Crawling {base_domain}", leave=False)
        while to_visit and len(visited) < max_pages:
            url, depth = to_visit.pop(0)

            if url in visited or depth > max_depth:
                continue

            visited.add(url)
            pbar.update(1)

            try:
                resp = session.get(url, timeout=10)
                if resp.status_code != 200:
                    continue
                html = resp.text
            except requests.RequestException:
                continue

            soup = BeautifulSoup(html, "html.parser")

            # Check if current page is relevant
            lowered_text = (url + " " + soup.get_text()).lower()
            if any(kw in lowered_text for kw in include_keywords):
                scheme_urls.add(url)

            # Find new links to visit
            for a in soup.find_all("a", href=True):
                href = a["href"].strip()
                if not href or any(ep in href.lower() for ep in exclude_patterns):
                    continue

                full_url = urljoin(url, href)

                if urlparse(full_url).netloc != base_domain or full_url in visited:
                    continue

                # Add to queue if the link text or URL seems relevant
                link_text = (href + " " + a.get_text()).lower()
                if any(kw in link_text for kw in include_keywords):
                    if len(to_visit) < max_pages * 2: # Prevent the queue from getting too big
                        to_visit.append((full_url, depth + 1))

            time.sleep(0.2) # Be polite to the server
        pbar.close()

    return scheme_urls, visited


# --- Text Processing Functions ---
def clean_text(t):
    t = re.sub(r'\\s+', ' ', t)
    t = t.replace('\\xa0', ' ')
    return t.strip()

def chunk_text(text, max_chars=1500):
    sents = sent_tokenize(text)
    chunks = []
    current_chunk = ""
    for s in sents:
        if len(current_chunk) + len(s) + 1 > max_chars:
            if current_chunk.strip():
                chunks.append(current_chunk.strip())
            current_chunk = s + " "
        else:
            current_chunk += s + " "
    if current_chunk.strip():
        chunks.append(current_chunk.strip())
    return chunks

# --- Content Extraction Functions ---
def extract_text_from_html(html):
    soup = BeautifulSoup(html, "html.parser")
    for tag in soup(["script", "style", "nav", "footer", "header", "form", "noscript"]):
        tag.decompose()
    return " ".join(soup.stripped_strings)

def download_and_extract_pdf(url, session, out_dir="pdfs"):
    try:
        r = session.get(url, timeout=30)
        if r.status_code == 200 and 'application/pdf' in r.headers.get('Content-Type', ''):
            fname = os.path.join(out_dir, hashlib.sha1(url.encode()).hexdigest()[:12] + ".pdf")
            with open(fname, "wb") as f:
                f.write(r.content)

            text = ""
            with pdfplumber.open(fname) as pdf:
                for page in pdf.pages:
                    page_text = page.extract_text()
                    if page_text:
                        text += page_text + "\\n"
            return fname, text
    except Exception as e:
        print(f"  -> PDF download/processing error for {url}: {e}")
    return None, None

print("All helper functions defined and ready.")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# All helper functions defined and ready.

# %% [markdown]
# Cell 3 — seeds (the 12 states) + save as CSV

# %%
seeds = {
 "Maharashtra":"https://mahadbt.maharashtra.gov.in/",
 "UttarPradesh":"https://urbanschemes.up.in/",
 "TamilNadu":"https://www.tn.gov.in/scheme_wise.php",
 "Karnataka":"https://sevasindhu.karnataka.gov.in/Sevasindhu/English",
 "Gujarat":"https://mariyojana.gujarat.gov.in/",
 "WestBengal":"https://www.wb.gov.in/government-schemes.aspx",
 "JammuKashmir": "https://jk.gov.in/jammukashmir-government-schemes/", # <-- REPLACED Kerala
 "Rajasthan":"https://jansoochna.rajasthan.gov.in/Scheme",
 "AndhraPradesh":"https://housing.ap.gov.in/",
 "Telangana":"https://www.telangana.gov.in/government-initiatives/",
 "Bihar":"https://dbt.bihar.gov.in/wp/SchemeList.aspx",
 "Odisha":"https://rd.odisha.gov.in/scheme"
}

# The rest of the cell, which saves to CSV, remains the same
with open("seeds.csv","w",newline="",encoding="utf-8") as f:
    writer = csv.writer(f)
    writer.writerow(["state","seed_url"])
    for s,u in seeds.items():
        writer.writerow([s,u])
print("Saved seeds.csv with", len(seeds), "entries. (J&K included, Kerala removed)")
# Out:
# Saved seeds.csv with 12 entries. (J&K included, Kerala removed)

# %% [markdown]
# Cell 4 — Phase 1: discovery — fetch robots.txt and sitemap

# %%
# Colab cell 4 - fetch robots.txt + try sitemap.xml
def fetch_robots_and_sitemap(seed_url):
    parsed = urlparse(seed_url)
    base = f"{parsed.scheme}://{parsed.netloc}"
    out = {"base": base, "robots": None, "sitemap": None}
    try:
        r = requests.get(base + "/robots.txt", timeout=10)
        if r.status_code==200:
            out["robots"] = r.text
            # try to detect sitemap
            for line in r.text.splitlines():
                if line.lower().startswith("sitemap:"):
                    out["sitemap"] = line.split(":",1)[1].strip()
    except Exception as e:
        out["robots"] = None
    # attempt /sitemap.xml
    if not out["sitemap"]:
        try:
            s = requests.get(base + "/sitemap.xml", timeout=8)
            if s.status_code==200 and "<urlset" in s.text.lower():
                out["sitemap"] = base + "/sitemap.xml"
        except:
            pass
    return out

discovery = {}
for name, url in seeds.items():
    info = fetch_robots_and_sitemap(url)
    discovery[name] = info
    print(name, info["base"], " sitemap:", info["sitemap"] is not None)
# Save results
with open("discovery.json","w",encoding="utf-8") as f:
    json.dump(discovery,f,ensure_ascii=False,indent=2)
# Out:
# Maharashtra https://mahadbt.maharashtra.gov.in  sitemap: False
# UttarPradesh https://urbanschemes.up.in  sitemap: False
# TamilNadu https://www.tn.gov.in  sitemap: False
# Karnataka https://sevasindhu.karnataka.gov.in  sitemap: False
# Gujarat https://mariyojana.gujarat.gov.in  sitemap: False
# WestBengal https://www.wb.gov.in  sitemap: False
# JammuKashmir https://jk.gov.in  sitemap: False
# Rajasthan https://jansoochna.rajasthan.gov.in  sitemap: False
# AndhraPradesh https://housing.ap.gov.in  sitemap: False
# Telangana https://www.telangana.gov.in  sitemap: False
# Bihar https://dbt.bihar.gov.in  sitemap: False
# Odisha https://rd.odisha.gov.in  sitemap: False

# %% [markdown]
# Cell 5, 6, 7 — Phase 2: generic scraper (static pages)

# %%
# REPLACEMENT FOR CELLS 5, 6, and 7: Full-Scale Crawling and Data Consolidation

import requests
from requests.exceptions import Timeout, ConnectionError

print("Starting full-scale, robust crawl for all states...")

# Define a header to mimic a browser
HEADERS = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}

# This will store text from all sources (HTML, PDF)
all_documents = []

# Loop through each state from your seeds dictionary
for state, seed_url in tqdm(seeds.items(), desc="Processing States"):
    print(f"\\n--- Processing {state} ---")

    # 1. Crawl to find all scheme-related links for the current state
    scheme_links, _ = crawl_with_heuristics(seed_url, max_depth=3, max_pages=150)
    print(f"Found {len(scheme_links)} candidate pages for {state}.")

    if not scheme_links:
        print(f"No candidate links found for {state}, moving to the next one.")
        continue

    pdf_links_for_state = set()

    # 2. Process each HTML link found for this state
    for link in tqdm(scheme_links, desc=f"Scraping {state} HTMLs"):
        try:
            print(f"  Fetching HTML: {link}")
            r = requests.get(link, headers=HEADERS, timeout=(5, 15)) # 5s to connect, 15s to read

            if r.status_code != 200:
                print(f"  -> Skipped with status code: {r.status_code}")
                continue

            # Extract text and title from the HTML
            html_text = extract_text_from_html(r.text)
            soup = BeautifulSoup(r.text, 'html.parser')
            title_tag = soup.find('h1') or soup.find('title')
            doc_title = title_tag.get_text(strip=True) if title_tag else "Untitled Scheme"

            # Store the extracted content
            all_documents.append({
                "state": state,
                "source_url": link,
                "type": "html",
                "title": doc_title,
                "content": clean_text(html_text)
            })

            # Discover any PDF links on the page
            for a in soup.find_all("a", href=True):
                href = a.get("href", "")
                if href.lower().endswith(".pdf"):
                    full_pdf_url = urljoin(link, href)
                    pdf_links_for_state.add(full_pdf_url)

        except Timeout:
            print(f"  -> Timeout error on URL: {link}")
        except ConnectionError:
            print(f"  -> Connection error on URL: {link}")
        except Exception as e:
            print(f"  -> An unexpected error occurred for {link}: {e}")

    print(f"Found {len(pdf_links_for_state)} unique PDF links for {state}.")

    # 3. Process the discovered PDF links for this state
    for pdf_link in tqdm(list(pdf_links_for_state)[:20], desc=f"Downloading {state} PDFs"): # Limit PDFs
        try:
            print(f"  Fetching PDF: {pdf_link}")
            pdf_filename, pdf_text = download_and_extract_pdf(pdf_link)
            if pdf_filename and pdf_text:
                all_documents.append({
                    "state": state,
                    "source_url": pdf_link,
                    "type": "pdf",
                    "title": os.path.basename(urlparse(pdf_link).path),
                    "content": clean_text(pdf_text)
                })
        except Exception as e:
            print(f"  -> Error processing PDF {pdf_link}: {e}")

# Finally, save all the consolidated data
with open("all_extracted_content.json", "w", encoding="utf-8") as f:
    json.dump(all_documents, f, ensure_ascii=False, indent=2)

print(f"\\nFinished processing all states. Total documents extracted: {len(all_documents)}")
# Out:
# Starting full-scale, robust crawl for all states...
# Processing States:   0%|          | 0/12 [00:00<?, ?it/s]
# \n--- Processing Maharashtra ---
# Crawling mahadbt.maharashtra.gov.in:   0%|          | 0/150 [00:00<?, ?it/s]
# Found 62 candidate pages for Maharashtra.
# Scraping Maharashtra HTMLs:   0%|          | 0/62 [00:00<?, ?it/s]
#   Fetching HTML: https://mahadbt.maharashtra.gov.in/SchemeData/SchemeData?str=E9DDFA703C38E51A19A7691F3B40AD4EE0F3DDA5DE324AC54819922BB3D36B63
#   Fetching HTML: https://mahadbt.maharashtra.gov.in/SchemeData/SchemeData?str=E9DDFA703C38E51A081772910D526AF0EDDF60A95235BCA1E7C80233A30F725A
#   Fetching HTML: https://mahadbt.maharashtra.gov.in/PDF/RTGU.pdf
#   Fetching HTML: https://mahadbt.maharashtra.gov.in/SchemeData/SchemeData?str=E9DDFA703C38E51A7909EC2FB46546FC0ADC6852AEB8D3556C79D437D47E3A55
#   Fetching HTML: https://mahadbt.maharashtra.gov.in/SchemeData/SchemeData?str=E9DDFA703C38E51A91E82A5FCFBAAB0483ADB704B47ED161F43EE2545EC67678
#   Fetching HTML: https://mahadbt.maharashtra.gov.in/SchemeData/SchemeData?str=E9DDFA703C38E51AED33CA69606C0CC2EF25388FB8EC7046E5E9B1E993657CEB
#   Fetching HTML: https://mahadbt.maharashtra.gov.in/SchemeData/SchemeData?str=E9DDFA703C38E51AB02E984835E89FEFDB316E301CE6A991F41C5D42B01A7D7E
#   Fetching HTML: https://mahadbt.maharashtra.gov.in/Grievance/Grievance
#   Fetching HTML: https://mahadbt.maharashtra.gov.in/PDF/SEBC_GR.pdf
#   Fetching HTML: https://mahadbt.maharashtra.gov.in/SchemeData/SchemeData?str=E9DDFA703C38E51A3D30C2CB15631E4E31F4E2AFF5E4258B33E89887D583052E
#   Fetching HTML: https://mahadbt.maharashtra.gov.in/SchemeData/SchemeData?str=E9DDFA703C38E51A8813422C6527A70BC8F386DEBD6292C54D5D3E063C32F598
#   Fetching HTML: https://mahadbt.maharashtra.gov.in/SchemeData/SchemeData?str=E9DDFA703C38E51AF93663E6569EFD2493B74079C9D4BC045DDEC4D398AED1BA
#   Fetching HTML: https://mahadbt.maharashtra.gov.in/SchemeData/SchemeData?str=E9DDFA703C38E51A9D67A04BA966CE9B96F78E67437811F5BC8073C49AE8C141
#   Fetching HTML: https://mahadbt.maharashtra.gov.in/SchemeData/SchemeData?str=E9DDFA703C38E51AEB31D461DD8183B67F07C60D4AAAA2026FB7F4DCFD673D35
#   Fetching HTML: https://mahadbt.maharashtra.gov.in/SchemeData/SchemeData?str=E9DDFA703C38E51A1655B141877065672B6A562E1EC5891E6D5A884AC6702F5D
#   Fetching HTML: https://mahadbt.maharashtra.gov.in/SchemeData/SchemeData?str=E9DDFA703C38E51A668ED132B54E2162E54C475F826D85C79DA948301E5F7772
#   Fetching HTML: https://mahadbt.maharashtra.gov.in/SchemeData/SchemeData?str=E9DDFA703C38E51A85D4A975C5D5142BC657258E23D57FBDAD7167545F0B41EF
#   Fetching HTML: https://mahadbt.maharashtra.gov.in/PDF/DBTGuidelines.pdf
#   Fetching HTML: https://mahadbt.maharashtra.gov.in/SchemeData/SchemeData?str=E9DDFA703C38E51A178A7905AEC2C82CFA6A7ADA9024B0C242EEB3AA7065D22A
#   Fetching HTML: https://mahadbt.maharashtra.gov.in/SchemeData/SchemeData?str=E9DDFA703C38E51A0C88CA9F14E2BAB30E38CD07F22F76EE9DCCA97D78964A4C
#   Fetching HTML: https://mahadbt.maharashtra.gov.in/SchemeData/SchemeData?str=E9DDFA703C38E51A78ED7CE6EFC1BA66278D9242EB6BD70623E4341DD9200A3E
#   Fetching HTML: https://mahadbt.maharashtra.gov.in/SchemeData/SchemeData?str=E9DDFA703C38E51A7F4D327BDEB7125DE0BA4AE1C51180C272281017EBEF6F7C
#   Fetching HTML: https://mahadbt.maharashtra.gov.in/SchemeData/SchemeData?str=E9DDFA703C38E51AF8D6D26D8FA7FEBA8680F51C3601BE8CE372CCCB64746C38
#   Fetching HTML: https://mahadbt.maharashtra.gov.in/SchemeData/SchemeData?str=E9DDFA703C38E51A8D6E1E4E8866EE600571B0A841AF768C93C24C5AEB049B3D
#   Fetching HTML: https://mahadbt.maharashtra.gov.in/SchemeData/SchemeData?str=E9DDFA703C38E51A28BFA30CC1E4590B8F718E4CDE619112BB546E172DF7EFEA
#   Fetching HTML: https://mahadbt.maharashtra.gov.in/SchemeData/SchemeData?str=E9DDFA703C38E51ADC627964D50030272270A16502AD36F854C3ED3BCB559D6B
#   Fetching HTML: https://mahadbt.maharashtra.gov.in/SchemeData/SchemeData?str=E9DDFA703C38E51AD2BE9F3A5300828BE4EFF8979CAC37F89BF462A7353CD060
#   Fetching HTML: https://mahadbt.maharashtra.gov.in/SchemeData/SchemeData?str=E9DDFA703C38E51A0D73B666D1DADFB476AD7228CCFCCECE862BCF76CF63E6DB
#   Fetching HTML: https://mahadbt.maharashtra.gov.in/SchemeData/SchemeData?str=E9DDFA703C38E51A018CC49F7EDF7669263658A643602B20E9A001B39A682B16
#   Fetching HTML: https://mahadbt.maharashtra.gov.in/SchemeData/SchemeData?str=E9DDFA703C38E51A903EC510F2DCBF009D17A0AB763F0C2343B13AF0AB323366
#   Fetching HTML: https://mahadbt.maharashtra.gov.in/SchemeData/SchemeData?str=E9DDFA703C38E51AE0CB048159E784170A4F3BD768B3A64E4772B0EF7B9990B2
#   Fetching HTML: https://mahadbt.maharashtra.gov.in/SchemeData/SchemeData?str=E9DDFA703C38E51AE7C10C1B9446574716EB93196C4CB29808753F77C61BEF29
#   Fetching HTML: https://mahadbt.maharashtra.gov.in/SchemeData/SchemeData?str=E9DDFA703C38E51ADF0B5B3136AAAD4C06BEFD7079D45EBAADC7F5BA9DCAA1F3
#   Fetching HTML: https://mahadbt.maharashtra.gov.in/SchemeData/SchemeData?str=E9DDFA703C38E51A1CE86EBA1BA63DA13D68304CE1D46C55A5B53B49580C2589
#   Fetching HTML: https://mahadbt.maharashtra.gov.in/SchemeData/SchemeData?str=E9DDFA703C38E51A6CA0A2358C3CEC1D64ECE777FC5CDB517A5E9878CFC6ACBD
#   Fetching HTML: https://mahadbt.maharashtra.gov.in/SchemeData/SchemeData?str=E9DDFA703C38E51AE50D4D8851DF49C43E0ED43F316413C64DC359D08045E4DB
#   Fetching HTML: https://mahadbt.maharashtra.gov.in/SchemeData/SchemeData?str=E9DDFA703C38E51ABCC44582035F06CB9B6B2704869FE16E9E8F561A36261D4D
#   Fetching HTML: https://mahadbt.maharashtra.gov.in/SchemeData/SchemeData?str=E9DDFA703C38E51AAC3D52BF09BB773555F3C82D946AC992C39B99CA73982F62
#   Fetching HTML: https://mahadbt.maharashtra.gov.in/SchemeData/SchemeData?str=E9DDFA703C38E51A63C8EB5C6B8591A03ACAAA73B08A2E9A0140E826A54AE104
#   Fetching HTML: https://mahadbt.maharashtra.gov.in/SchemeData/SchemeData?str=E9DDFA703C38E51ADF6AE1F1FBCD6E5590683EDAFF0DF60958CB2C07261F364B
#   Fetching HTML: https://mahadbt.maharashtra.gov.in/SchemeData/SchemeData?str=E9DDFA703C38E51A1D7F9196D9D63BED796B8715593324631CD0734AB93952ED
#   Fetching HTML: https://mahadbt.maharashtra.gov.in/SchemeData/SchemeData?str=E9DDFA703C38E51ABD801C85A5E1070827B2230746448BA9CCB9B577565F338F
#   Fetching HTML: https://mahadbt.maharashtra.gov.in/SchemeData/SchemeData?str=E9DDFA703C38E51A1FA3AA7E67D54CF402FD88D88C64949C41EC3238C8545A71
#   Fetching HTML: https://mahadbt.maharashtra.gov.in/SchemeData/SchemeData?str=E9DDFA703C38E51A150D8D3BD5BBF9E579F0BA8D2D926043D82C17776CB73469
#   Fetching HTML: https://mahadbt.maharashtra.gov.in/SchemeData/SchemeData?str=E9DDFA703C38E51A4B35AA6BF0E14F175519B3FFB55DBFB0420845CFD04D6FA5
#   Fetching HTML: https://mahadbt.maharashtra.gov.in/SchemeData/SchemeData?str=E9DDFA703C38E51AF1EB6E005AF00CE987BDFC9C0AF5E19F88A435E8941B1D64
#   Fetching HTML: https://mahadbt.maharashtra.gov.in/FindEligibleSchemes/FindEligibleSchemes
#   Fetching HTML: https://mahadbt.maharashtra.gov.in/NSAP/NewOrExistingUser/NewOrExistingUser
#   Fetching HTML: https://mahadbt.maharashtra.gov.in/SchemeData/SchemeData?str=E9DDFA703C38E51A154AF155ACB2A8B2FDDAB7A49A24E2B13EFE22C60B340852
#   Fetching HTML: https://mahadbt.maharashtra.gov.in/Grievance/Faqdetails
#   Fetching HTML: https://mahadbt.maharashtra.gov.in/SchemeData/SchemeData?str=E9DDFA703C38E51ACE99921E698B1EE85995B38445F14746E1B0DD7E66FFF88B
#   Fetching HTML: https://mahadbt.maharashtra.gov.in/
#   Fetching HTML: https://mahadbt.maharashtra.gov.in/SchemeData/SchemeData?str=E9DDFA703C38E51AA86467549C6E0CFFDFD61E992C8610ED352EC9DEF886C9CD
#   Fetching HTML: https://mahadbt.maharashtra.gov.in/SchemeData/SchemeData?str=E9DDFA703C38E51AE6CC3420B0C53DCEB5F351B3D2A9E2CDC4ABAD8058B38786
#   Fetching HTML: https://mahadbt.maharashtra.gov.in/SchemeData/SchemeData?str=E9DDFA703C38E51AFD83FFC8C5199983E26D3BE9645241F26E1947ED73B2823D
#   Fetching HTML: https://mahadbt.maharashtra.gov.in/SchemeData/SchemeData?str=E9DDFA703C38E51A6BF9C803E998CF7698D365C08C21682615495BBF3667A9D0
#   Fetching HTML: https://mahadbt.maharashtra.gov.in/SchemeData/SchemeData?str=E9DDFA703C38E51A3DED9E25855FB26766A86AA048E5C167661433728284252E
#   Fetching HTML: https://mahadbt.maharashtra.gov.in/SchemeData/SchemeData?str=E9DDFA703C38E51A14D02B3B9D1B4C86EFDF20E447AB42D8B9E7FDA684F6DF59
#   Fetching HTML: https://mahadbt.maharashtra.gov.in/SchemeData/SchemeData?str=E9DDFA703C38E51AEA9BC48B6A7FC6028D83FB435163D2E3D6296333C81E963D
#   Fetching HTML: https://mahadbt.maharashtra.gov.in/Grievance/collegelist
#   Fetching HTML: https://mahadbt.maharashtra.gov.in/SchemeData/SchemeData?str=E9DDFA703C38E51AAB02274CF2CA0B03BE063BF30732AFD192E705F070148D56
#   Fetching HTML: https://mahadbt.maharashtra.gov.in/SchemeData/SchemeData?str=E9DDFA703C38E51A2C489D8FEE1DE79D3D179EC97AB141825125A9561892EF10
# Found 55 unique PDF links for Maharashtra.
# Downloading Maharashtra PDFs:   0%|          | 0/20 [00:00<?, ?it/s]
#   Fetching PDF: https://mahadbt.maharashtra.gov.in/PDF/30.pdf
#   -> Error processing PDF https://mahadbt.maharashtra.gov.in/PDF/30.pdf: download_and_extract_pdf() missing 1 required positional argument: 'session'
#   Fetching PDF: https://mahadbt.maharashtra.gov.in/PDF/7.pdf
#   -> Error processing PDF https://mahadbt.maharashtra.gov.in/PDF/7.pdf: download_and_extract_pdf() missing 1 required positional argument: 'session'
#   Fetching PDF: https://mahadbt.maharashtra.gov.in/PDF/RTGU.pdf
#   -> Error processing PDF https://mahadbt.maharashtra.gov.in/PDF/RTGU.pdf: download_and_extract_pdf() missing 1 required positional argument: 'session'
#   Fetching PDF: https://mahadbt.maharashtra.gov.in/PDF/PhotoSign.pdf
#   -> Error processing PDF https://mahadbt.maharashtra.gov.in/PDF/PhotoSign.pdf: download_and_extract_pdf() missing 1 required positional argument: 'session'
#   Fetching PDF: https://mahadbt.maharashtra.gov.in/PDF/13.pdf
#   -> Error processing PDF https://mahadbt.maharashtra.gov.in/PDF/13.pdf: download_and_extract_pdf() missing 1 required positional argument: 'session'
#   Fetching PDF: https://mahadbt.maharashtra.gov.in/PDF/Aadhaar-seeding-process.pdf
#   -> Error processing PDF https://mahadbt.maharashtra.gov.in/PDF/Aadhaar-seeding-process.pdf: download_and_extract_pdf() missing 1 required positional argument: 'session'
#   Fetching PDF: https://mahadbt.maharashtra.gov.in/PDF/How_to_check_for_aadhar_seeding_with_bank.pdf
#   -> Error processing PDF https://mahadbt.maharashtra.gov.in/PDF/How_to_check_for_aadhar_seeding_with_bank.pdf: download_and_extract_pdf() missing 1 required positional argument: 'session'
#   Fetching PDF: https://mahadbt.maharashtra.gov.in/PDF/1.pdf
#   -> Error processing PDF https://mahadbt.maharashtra.gov.in/PDF/1.pdf: download_and_extract_pdf() missing 1 required positional argument: 'session'
#   Fetching PDF: https://mahadbt.maharashtra.gov.in/PDF/popup_blocker_guidance.pdf
#   -> Error processing PDF https://mahadbt.maharashtra.gov.in/PDF/popup_blocker_guidance.pdf: download_and_extract_pdf() missing 1 required positional argument: 'session'
#   Fetching PDF: https://mahadbt.maharashtra.gov.in/PDF/2.pdf
#   -> Error processing PDF https://mahadbt.maharashtra.gov.in/PDF/2.pdf: download_and_extract_pdf() missing 1 required positional argument: 'session'
#   Fetching PDF: https://mahadbt.maharashtra.gov.in/PDF/Forgot_Password.pdf
#   -> Error processing PDF https://mahadbt.maharashtra.gov.in/PDF/Forgot_Password.pdf: download_and_extract_pdf() missing 1 required positional argument: 'session'
#   Fetching PDF: https://mahadbt.maharashtra.gov.in/PDF/SEBC_GR.pdf
#   -> Error processing PDF https://mahadbt.maharashtra.gov.in/PDF/SEBC_GR.pdf: download_and_extract_pdf() missing 1 required positional argument: 'session'
#   Fetching PDF: https://mahadbt.maharashtra.gov.in/PDF/17.pdf
#   -> Error processing PDF https://mahadbt.maharashtra.gov.in/PDF/17.pdf: download_and_extract_pdf() missing 1 required positional argument: 'session'
#   Fetching PDF: https://mahadbt.maharashtra.gov.in/PDF/Forgot_Username.pdf
#   -> Error processing PDF https://mahadbt.maharashtra.gov.in/PDF/Forgot_Username.pdf: download_and_extract_pdf() missing 1 required positional argument: 'session'
#   Fetching PDF: https://mahadbt.maharashtra.gov.in/NSAP/PDF/RTGU.pdf
#   -> Error processing PDF https://mahadbt.maharashtra.gov.in/NSAP/PDF/RTGU.pdf: download_and_extract_pdf() missing 1 required positional argument: 'session'
#   Fetching PDF: https://mahadbt.maharashtra.gov.in/PDF/Aaple Sarkar DBT Portal Help file.pdf
#   -> Error processing PDF https://mahadbt.maharashtra.gov.in/PDF/Aaple Sarkar DBT Portal Help file.pdf: download_and_extract_pdf() missing 1 required positional argument: 'session'
#   Fetching PDF: https://mahadbt.maharashtra.gov.in/PDF/DBTGuidelines.pdf
#   -> Error processing PDF https://mahadbt.maharashtra.gov.in/PDF/DBTGuidelines.pdf: download_and_extract_pdf() missing 1 required positional argument: 'session'
#   Fetching PDF: https://mahadbt.maharashtra.gov.in/PDF/90.pdf
#   -> Error processing PDF https://mahadbt.maharashtra.gov.in/PDF/90.pdf: download_and_extract_pdf() missing 1 required positional argument: 'session'
#   Fetching PDF: https://mahadbt.maharashtra.gov.in/PDF/20.pdf
#   -> Error processing PDF https://mahadbt.maharashtra.gov.in/PDF/20.pdf: download_and_extract_pdf() missing 1 required positional argument: 'session'
#   Fetching PDF: https://mahadbt.maharashtra.gov.in/PDF/33.pdf
#   -> Error processing PDF https://mahadbt.maharashtra.gov.in/PDF/33.pdf: download_and_extract_pdf() missing 1 required positional argument: 'session'
# \n--- Processing UttarPradesh ---
# Crawling urbanschemes.up.in:   0%|          | 0/150 [00:00<?, ?it/s]
# Found 5 candidate pages for UttarPradesh.
# Scraping UttarPradesh HTMLs:   0%|          | 0/5 [00:00<?, ?it/s]
#   Fetching HTML: https://urbanschemes.up.in/Home/chief_minister_nagar_srijan_yojana
#   Fetching HTML: https://urbanschemes.up.in/
#   Fetching HTML: https://urbanschemes.up.in/Home/mukhyamantri_nagriya_alp_viksit_va_malin_basti_vikas
#   Fetching HTML: https://urbanschemes.up.in/Home/nagriya_peyjal_yojna_1_lac_population
#   Fetching HTML: https://urbanschemes.up.in/Home/APJ_abdul_kalam_kagriya_kaurya_punj
# Found 0 unique PDF links for UttarPradesh.
# Downloading UttarPradesh PDFs: 0it [00:00, ?it/s]
# \n--- Processing TamilNadu ---
# Crawling www.tn.gov.in:   0%|          | 0/150 [00:00<?, ?it/s]
# Found 0 candidate pages for TamilNadu.
# No candidate links found for TamilNadu, moving to the next one.
# \n--- Processing Karnataka ---
# Crawling sevasindhu.karnataka.gov.in:   0%|          | 0/150 [00:00<?, ?it/s]
# Found 0 candidate pages for Karnataka.
# No candidate links found for Karnataka, moving to the next one.
# \n--- Processing Gujarat ---
# Crawling mariyojana.gujarat.gov.in:   0%|          | 0/150 [00:00<?, ?it/s]
# Found 0 candidate pages for Gujarat.
# No candidate links found for Gujarat, moving to the next one.
# \n--- Processing WestBengal ---
# Crawling www.wb.gov.in:   0%|          | 0/150 [00:00<?, ?it/s]
# Found 0 candidate pages for WestBengal.
# No candidate links found for WestBengal, moving to the next one.
# \n--- Processing JammuKashmir ---
# Crawling jk.gov.in:   0%|          | 0/150 [00:00<?, ?it/s]
# Found 0 candidate pages for JammuKashmir.
# No candidate links found for JammuKashmir, moving to the next one.
# \n--- Processing Rajasthan ---
# Crawling jansoochna.rajasthan.gov.in:   0%|          | 0/150 [00:00<?, ?it/s]
# Found 150 candidate pages for Rajasthan.
# Scraping Rajasthan HTMLs:   0%|          | 0/150 [00:00<?, ?it/s]
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mz1DFk+uTDZkkpNOlKd2QLqZWwV7BoM0ZnGkmMVkyUhQEf7wJhG/4I68V5/yYfkMOyZArFy1Tkoo4guoatgGwBjt8j8ECoO3IWevUAMMClrDMToX7aYxwgM
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+myivDsjQAMrH2a5R4suc37g6OPS952Hs5kyMvr12NdA7oVa/R4K0xzO
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+myr95ieSxTU7ayAyog0yXNIt70d42otUGn90I3iigG9AxayQqHcb1wa1JU59P14C8ccUHpCZ1xI6Pe+FQaJYOpd98ZCHbimdcM=
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+myyPwrLfVqZ0Xt4N1D29sLT7iXmuV+YZGm7Y+jXcAQ6HUyFYUn4UEImN9EBoJLgwsY=
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mxJ8W8JVBS2w4fNkumK7YYCBFPFNhSenWuxpU1fLOEUMkFJ9AtFWffXDqvEd5k89uELLdtm7qGPGU7A/UUAfUVY
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mwtsSGexkpB9w/nDNWt5qFHYIWvorDJoOAnSY3/00UjWA==
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+myIHVjuyjYWX0QcVA9tdBaxGQgbaT1Bv81Wx0L5o2YZjJRtLtom4vVoIlzrhx8j3JYMyqzGPsVSwA==
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mxdDfdh7kTWFca6nlNrDJeOlwFufuKemxE=
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mz3GjFYIukopvxykHZNJOv1rzThMDIRgE+3dvPQ3PE+wnO+eEa24GhY
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mwiHropMccvfggLlAm3b0aPeXGg/Rgd7c/P2rQRoHtLZuKbPTqArBHWznh4enf1UcNt3JAf9UChpg==
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mwGyjHjn47tCV139IhpKGMajmob84Q+hzYvbtJpdqw9GlczxOG4DNTfinl3Nzw1gBE=
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mwWTivHp8qhRPmiAF2mKz0MvKbKmHjTvb6Jiz0eXwVv1iq9qEtshd91kff/tJ5M5W8=
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mxwpPWHZgdqOybR/gq6PFcfsECOLzwxCJLxRWwFTSrFNA+f2aoUoHIcXar2SPWnoUs=
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mwCTgT7r5o+M3KRykXwilu2bwc1YYvfgMYUmC6LH1p2VU3PAYYkrLNv
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mywXFKPFw/JDKMS+5blOcsT9N6Mp85/d9TqDq+HwACHtMA0hPMWqlxbaPU4G8Z6pFLSDHjp1/+PV7vjgkalgQxq
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mwZ82r1+dlX5hZ5vZeUJzVv9n0+gRReJQ+jiBULjl0cSNsmuc5awqHuX0QZ5Akk85SCnYOtfD+DuQBm104H4BkWY3yYNYhJLKKG+L7oou/r4T9T82G2pO29r4o5P8FhSuJG3SQFr0zu8A==
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mwzletdShUvPBALNyif9yiK7IU+0LO7J1Yr19tecMEkbLOuytfGFaWBt7C//oYxx4w=
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mwx8IkUduXUMDP8i+qHnn630pUlC++QZDjbK0Z5Ts3Hd/KZ10sUfo0ruwFJJKektUOXn+cdtaFgvQ==
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mw0E6Si9jOra1hnHz09Jp4AZ9+IcPk7EyBWcJ0bfTMwEQ==
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mxnt2NzVm5e5wAU4vRMKphF3UeLuzOA0X1NR6IbUZRdeMOsRDqEm7DbTdHQSp+0gkCBoNWg1RcVYw==
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mxnr/bAv6wuG040X/ShZqxySacllvtpLthvHv3AXKFTIlm2bWkHwcO3zNeEtNm75FLdOvH+M2h2IUrrn8k46u62KiVa8+jJV+B0FrL7GnUP3fPNQ/Jh5TmXuWo9uFtIqkUamB5IXG4y4g==
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mzpoC9YqINhL8MH8jjM6vCyUuWm822gcrviKlQthQFfZw==
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mzbR558ldtpF09aSb2lU4pfinDZKOHBbVay1Ue4ViSGBr6/JmBqls1AU8u/yoCWi14=
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mxkCpSMGaHEwQlJ88FgLOS1J3naOdfFPOFR801tP+5nq1uBzcLn2eCL
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mzpzl/HltqQaGAhtCT9mdqu3a2ccmADHgg+PAZn0X2V7A==
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mwuLgX/gKdDlWDkVJ0tEUWiudoIKePz3CbFLkDowHUY87jwma/+li+A
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mzWtyOjuifQGCnkICc0Lqd0yhIx+rTFu+mS3vQw0WQ0uu2xcu5k2j4ALm/j04MCbqsmoUUYQMXaxGgJCLIJuSMbPj0kCbNmtJk=
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mwe9HbwozA5Xn6riyWZsq7h70AoDPS3JXtbdeHNkTPeInXq1KL2y/hIhQ5TobD3u1XdGsP7ZKDRZ6jHP/vtGv9D
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mza5vfZj5H7iNp1bV02umh5eswVHPwDiddWDzeO5Wbq1pHdugw6Zq3OqjVwPj4Tq5o=
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mx6sD893KDRDzEbqd3eqIpPHDPBWSOIUlNR7hiwN9O1x7i48pfH2kM4nX6GNbRcFJm4bW6Ig40evn5BdZB1woCj
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mwL9h/zPvf7MGc2fWfyvc/C/RZq06OmvYg=
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mxkvKHpBmd4MhCvxSk2QetK1EUriMHn0vmCf/YxhgPvyW/0/33HbWbA
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mw6U6cPveBgmN/YW5ASqSpBE+rwHcO6OhLFaKraPO2ouywlWkQ3Oiq0XPR0Bu0caDVw39sFWLobO2p1bvQ28W4ccv07qaxN2yA=
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mxgq9TGNnPLUO86Oon13uS7eSuP4pIaHuEZeVVKYTh5ntkZTtR2gq8FVnaVT1aKRMs=
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mxwsDZ5SnXqTLxpIKBM2Njn4TaGR5PO5AsYvldQlmlM7wP222sBvNlBEK8iGMRRBWzx5ob6SgSnzA==
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+myQeOuaII4NblhPQqZ9Du6DUTigK7LQPQpa4ZcDbEOnAT2KmgTENTcIoLWXl20cCOI=
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+myKttXtgYbIr1wRGSwVsKJOOsSdoF0wJRANNVuj14DA70rtUZffspki
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mwXrpUA/eBFul40mBPIO01B6BLFwAVrtAwqUKFIBdZ6kPPwMNDjfJTdss4Oa3aiwyfgz1uFtLGLyQ4Wsg0yLVSecoGqj6Dvaeo=
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mwtHSn0gijyy/qZsCKIvD5hONHl53uijpe2/QmlAN37QVdyKfmtMAIeG1BXnfWiFojijgCrMZhIPA==
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mwup+pS8LPD4SnLtrXbs6xxsjFnS1F63/+dH4PCYCYmFvp/NlrYVI42twY2PJQKG9CNAhmV1IOPfQ==
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mx/H/awOgKNWF1N7k1K3nL0v0bbDbUppTinmK2B0+GUWYNldawMR3aUGh3BeEgZIO1HHXbxBkyOlL5ED7XPwPr0BG4Ktp9wPRI=
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mwLxj4DE7LGm+I7BtlLOjEyvkXTq/GQoqtvfh13mCLSdut5n/RlhBiLt1bRuCCoUdmk8HC9l7+3AMLRkfh16g0n
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mzaabNpCwSYxshbjMbgTEYeZML3UFsatsFcupF25cKpM1w8J+SYwTCcbTSFs3L3XZnpTJPjK49EXA==
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mxjGXy7jv4RqIDqoJixj5nfpKZIKwhfThkfBoDEjkssrvl8dEo+sJ1ksQH0a/3Q+YApyClrjVkzjdpPKIKjdOw7
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mzWbK5uGwRP7GCB6Geb7lb1a+YBlNyF6kekhrkDfQ0P+eXUp85my/xvwWHuMoslf+cGopBjNmguhpAArsH0qEKL8F77qYwMhakSTDAywFVNDmfS0SlTNKIO
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mzDTV7eglJD4kFM+ytNeVMx+j6+6QgDWWU=
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mxnWUbmivaSqiUCXTopw7UuUMqHhhoqp0hcERNDqP5Y3D7hHjZvmIZFO5c7qCagVEG7IXMVOIAFgCHybqgvUftgs2CFlKLCoUI=
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mzeEyDQJhxFKj9gJozHNPQLff4Qvkptcw7QvlEOyoI5xZ4yJxZoH1oeT+zl+oHTYzJeDKH0XoaD8w==
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mzdGFVoi7asn/GpqUJFzTGi+GRsWJ1ZSUk3x0R+FpFo6+q7C9B0ZOVJQILMcmfi3gKa2qLzymHE0Q==
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+my3YzBYJckRrsIFUME3oMy5ZKqIyruRL9WGfNJW2BOjrQ==
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mx0UtiZOMeUieq3Vf9aqwset2q3JvCbsXfUEkGoehBZiwrfm2W9/GWP
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+myt8JVz743lTQHFxFC9u63c/V+P8WdKCiKUCUXoZKSLaAcIRpb+GNCYXThjgAYFMU8=
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mw1PoCWCZaM6g0JannIR6W6EeFkwBVLAkQKa6RkQwd04lK33QCpLHHiKhCEHbK+WbZhgvnsKhaXiE8y6C+gYuHc
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+myRbi1ECxgRy4W4jrG7qJ2DqJc3IZEiF/38e0cmTdC2AXyQF3PB1DozQu1E39hnW/A=
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mwz6RjM/9xI9mRuFiEkdmBQwUf0rblHNWY=
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mzsWf+tsoMjImHbnFe1XtEI1fZnghMKJoyt47IdSD/xhvRb6BYOlqnh
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+myS7z91HnVzT1+PTgU6E9kdh4jJf9FTvbU=
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+myQQohTPR9C2sKf0dvh5e6xsowFlypkAR8QKSlY97aSe6tFDC+SfrgSdhbqfXe+8YygZPVtud7bR09ShCS60yt8s48GsDVnrKa+Q/LRqsnxzg==
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mws5cngY79pRu7SsXPGtq2tbDt46ogZXkpAmOEsuSRHf2CMdO2IbL0Jj9cpqWP7c+pP7XEpyp66dYriQ10fsIqA
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mzmicjorEw50ckdoFO+szVppS7QnEMVuoCr1lvTJfS3JkHkeg7ios4GorrPgDYISTDI30HaodmoMSitCkkFl6gW3P6XKqFa6czCojbHavcqBg==
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mwKEoIqXsbTxXCCX9d+jz4TIV8AJdaHYbiy08u8ZZfuAHfRnckOdAskrtijENm/9q8Nbe9GOKc4sOAKoj3yJa/G2AGqrse2N+E=
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+myvsWcLEl4QGTpPecx06vLZ7zyhwcYUCgtIkyh/m3mleOG3l7dS5+7N
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mzclLqx49ojCJ/MViNXabit6oHX+Zwo6OovZSYo86qex6IbtkD1jZYG
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mz2Pec5IFjV/cEJeMHylzfk39luhjUGqSRVWbuMonpIDtGioDPy9/BI
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mzORooZ/tlXUcN0EOl0yMLm9WHlphzpWsr2y7xn6dMLtpPWZoJ8I78B
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mxP25FSh86DSLcH9yUJ/fgeER9PNqYEeZg2ony4Z7vgZKqg6ADQv/rXwkxP6igQvHGYUDsHCHtqVG6kaKeOzCdQ4f+r2vpZEi4ZNbAUihNCqA==
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+myVEaVTCC8eB/H5rTKq299rejkKV+Kqkqs05kp8G5XcQw0vFsu78JYgRzlkJvzsdXAQtqSJyX5c/Iso63+qyVQO
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mwrC+qxd9B29SmNZ1CO6ctkwzIgv/xvM7jL93ci7rFjxPkRF+b4mdrVO5CNW6HfPJ04jjOlcUe27w==
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mx7K748L5jaS7Y5q1q0YrRMEkIui4vNZm4GYHup5+FQYenAaAkGnqVhYa0RX8X9hIhnrG1JKjY9N0boKXlWJbLORVB9cD7aM8MeVS0qyZWQqQ==
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mzpuMLwjya1yS9jwYJuoWeIqhGk6JHnejKAVRbW6zYeHQ==
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mwU/6eAyWPgfLmhA5gFe9mz89Pon3hd5iQzTKtjk1j7NfsGT+xKvXF7
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mwbeHYBcnEut+yfv4irsdLXfopJt8MVD5x40Os9t9HlcKRi32QxMsoJZK4D2FtEpW3DLRJMpOzXGw==
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mzqzBGO9Bi1EaEMpzD9iZQbLo7YDAahhPo1py11OL07+YibwQvsdn927jluiugvc6OpTbKOyxpLjQ==
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mymDPiYIf7hms4jwjVb2uCvY2/GVAfsT9X0yZs75KV/VGWM0C/c98LKvP+vw0531io=
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mwLB1IipE+wXd9DqnVm7oMLmA/ZY7+zqLgy0/PtUwqdGtqloHdIPnhc
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mydjTQglpThVHpQ98jZNW68K4YL4T3awa3S7ddPJZ+BOmJT5OENIrO3cmG8mPVozG4=
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mxvhpuVlGyg4PsR6Uw/9noik+koIeq+Njrb/3mjvgiHWgf4nvpKUD2L
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mwLFi7U4ttMN2Yk5BQZ+fID6NyHdNVIEP006e8+i3N5yv8Y6JtOPZBjnfkvKCmiUeo610i/1z8qbw==
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+my6S3AbtoPh8I/jtNuLW4IuTORuw0/7Dv8GwRWXvYtgCV+D0ro2WZ/+2icnl7vjKypTUStGvKBU1HvGdrmrpAi18L6HQ2Bbe9xP1JEWVV7FygQvWxfsMskpdHpQbcKl7N0=
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mzli34zfcXZqjBDDqsSTMcxGf8BUqvv4ZarciYi8MDM4B7HPQV1DJ1H7xFwfhadbf4=
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mygxsAtAEtkEPUm6+6hFalQ9wz60ocYbHpr8XAMev8r0FN6BrUDHFmssuZ2vChmeRg=
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mwccTmgL5FJA+AciVvpV5cHI0nAwPiubP8ljs4W7GQSGNguQbV3qDGeBLPNOPn+4zI=
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+myolt6711hUaicFAKhlGRgTeSbmlB2C+L36fqLBa/fI8TapmcXYEzne
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mxzncuCu3Mu5FP3WcesGVDb3lLJKRH46AXU9mk+eIXJ5A==
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mxsCPcqEEY7mMkHebT2RnO31gEHI8BtgKfH8ARzy9yDxQnlvT3J+Rr9+EfU/pY1vYs0azKsT4ub/Qlwy3TXe0kk
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mwW89k11XWt0YGT+yd12L0qRy4HnpnXojzLcBHkOQ3IfqymT52EDfhrKcEDUmzoghOm0zjf6NO9sA==
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mwhyaSq55uXvoRua9QdAVCZQEZkC1T23BXVGGWXA6/JpG/Aojccp4XIPgSDTCdRSHX1BuXWmO54YyugA66bb2DY
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+myHOpx1eCrNUVBmc95bYAH37kYvycpJfryUr84Z3j8NbzTGzFGSY6LpF3bEbVuQ1+9g9r1eBEmUV6PIEj7zUFtq
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mySbxbzHp/NWAoChPeVr5bhTDP7nVyY1Z80OSjetuieSfA+eRP/s8ogN7+uRlquBD5wrEkVfFLZEg==
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mznUzswNVI01uCsClTMfuEvYK0bPUnc48F7XXOHD22W7VyCOob/JZbyC7GFkzxDcIlCWTOJj2x3Mu3wupYLxVZy
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mzWsJsaPY1YHet/flRZegsO+YIJaR3GhOrT8F/ZeuSqeG99NSJ/NUQNUQrzv+q/7Xw=
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mx2WtSeg9X7RVMPG9V+V2noO2XONIMZZqQKBL5vKFXFpUye7BW3f5pFtASbPjRUzQzeKPZnDNaJJiYkdDPXVHK9
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+my/AV6yRgvnor+phbibZuwqAQV/4i4sWQdys2m02FykHXoCzCQ8t7LWWO4fI3SDnbZyPDeT4WRyysfzCpGfqYay
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mzgNtjQz0ei3kB1j/ywAAlIcx7xYqcDKBM=
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mztkTObJsG9dM3olcjvR1phIyNK6nTkZyy/QkAJ2vGOgrVU6m0NYonJkkxb4YNpJ68=
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mwvE6kbYJFa4rEPABLKBkE/uCouC4I0E6tn9ZlkjtKuWVKpMSemWT4joB6SD8FyWlIhPWjEJE7qcgsiImtVpJ8h
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mzAhAg3LoxMIVw7o5P1pgNsl5Le21UzvggiIu/QVi0ezQ==
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mzKPPTxw4tERdpay5TuyT6ml74F2CIKK34HSr0b+BvbJ8zTbzMYVLGTBnyLsxV+Wb5/nwZjJKYcmfUDAmzOA2fg
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Scheme
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mz8wTvfGPh6Jaq5nYDNqH7Vd/9U+4oqKQm/Ar3DTDM4bCxLGDoWyFuUpkx5dbR53yILkvMkw3hSeXRjOwcXdODI
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mws+ztVUgkhhzBCuUlXISDAyaY/QG4TDdxwZ3a8jYmoUTOfsBRb1z7C9rk5BTOhqAs=
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mzyQUccc9Qb9+HDx7ALMPuAgiFmPmydXpeONhl4NBfDb/GNlIBGyi/D
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mw+I62KB2KlHsPUygBfm1iYPovvww0+BHwrvRkEuxLoBw==
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mzMSD/G1GSP5I7prdJNgn6zqzqaJaZP/61diX8skZgesg==
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mxniGNKNXSdclCyEq7BaBbsp4lkRNLdCWnX7LP0iE3FIfVgQmC9/j3WbN3gAKvi+WUh28LtaDC6Fr5ty5KxmbOalOyyk4SeZCo=
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mxb7uoYqj3azFrx5fbk+W5WQRiq5wt9RQ91pFg3mJgd+UpmJnLQWjvTyu/uLal1Qx0K8JjrBNG03aVw1U3tybIh
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+myXXe5QJba/RLAeovj+etxivmeMF2Axa9DaD34l1U3zWGY+NOvrxcXoxbSHzq4Nd3lGZ3fDxIZGpA==
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mxCI5XeTH05Gj68UPCPIEluqiz7qi3+yjU8UyMbCGPVwnQEnE4XUNQdkjPLES4BoWk=
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+myRzlHc6SxOlCOyPBJZtyB2HVdziaYEzPNh5RzqFQSvXRwH1EdvVLjMEW2jBdUZL25O5SYVXKbHFFqQPi/ka/UyPd9euN1ibVYEmf+fHWuwtwZWayejwa5v
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mxPV4qrUn3mowgBgGQxu4pcIQQSdZn9vDroDBRhC9N15QA7eYx7s4KR
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mwq03V5uAVbN6oqDmrUwOVBdjPFcHzHyU0b0jWwUYJDPFRHRkUme2HS/wlxceN4qBqZBOTyURtxyLiOrUudNqxw
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mw3eXpneSdGNVV9wqdL7SIRVq/UFSgUxTi/+JSMdiPdt7t6i7/xM3q5wVobbVMSNPu92SZj/e8OScVdRm39NjmB5D2K5u5FloE=
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mxxn+T7zNV1Am/RgnPLvNJUBVHlMrphvr/gxG8ny2gcSsAOpZFCZNpFsgNipEg71ZcN1Ns43amwyQ==
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mxQRy1gkx6vh00+OGJphSXrXEynu5IM/Gn+6AQicyJ95IE7MN7cvlRaP9JCbcbn8qC7nFASGUg2O7sg/+XBazXyzHtYgfKqErM=
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mzIhUqUWTV6MfP8o6fOLIoPTcPELol8zbEqJ0L29BL4OVRUg4uUF546Msvh3DagLxbBYlg+yHc+Sg==
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mwDZkQd+dIAA7fiL+rpOA/kwk2hvkVAS0RQdtdZaun00nUoXVvKyjCvvZ0IHcmsWjqhkv0vGEv6Fw==
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mxnSvwvRI8PNyktU1/tBvA3RBPZGLXJtwUckyk9WVA4iJChiPuzWaAk
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+myHNMmrAmpZFTK9x5xvCtf5MgcULWBQywKyAe3ZYtOt3stQFsIC78HmJyYrRfIliHg=
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mxEVTuKpW95MPMrypnVgKp5787ESyeaTHmxd4RLbjZPt1X6Au6S6z8qOorhxFZEUKxVMZH2udcmUGdC3LEQn3Io
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mwuoWOsaSIzFPy9wDdLH9sqALgYDaF3b30QGm8fKKR4JzdO7lXAi7AhsnFQjjZf/Hm1bJMMGvASgsO9ImIQcUQU3yv0iJsg/Ac=
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mxvzC1gC8Wguhb/tsrQGHSPmbu6edE/SRQf5d+Scegy3Iy9bdv57zd/rbgbLYg7WuEDxPMEVSe5/YD5MWpnHe2CZRlSnPS5Owc=
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mwcv2oj2CET6p3eE8/NTsrspG8bxFifdew=
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mwJ6pZRLZbz3dnegrNDA/4Ekg5RUB7MLgQv7oiLkXrOUQsu6Mo8S0uSwCTRG01QukZLJVvt543i8cco/VqRa8c+
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mxjRemvjq1HNr4vq5FJ+/LyhT6UlHOnyGjXrJZxgUrNTqD6suKWvNHYTby1v0SY29OtNOLo4EHZ3BiW2V7mHFcRsCQTa8baZicb0qBoJdKeUw==
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mxBziGwqYfEr79huZSnbA/g3O4rEQ/IQ+GnlRCvQyaNxQ==
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+myaTRcdZsPVo7mTCctfSFYEl47TTdFez5Wc3aKJNGllL99woPU34wYZERkFUAE/S8ULulLvk+L+gw==
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mzMm1EWkSMCqnq9//4u8DGqv/pM5j1HB7a2OqqwLcnvwKG6mZphwJvMDLbWHDhUE0c=
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+myUZHNR0bZFJfTbieGsBdTQfvWzfZk1tmOVDyZINmqOCY/c9c/nH6UxYynPts/kvh4+fws24s8aYVcUkqZktEdN6d9U2OX5dqLjMyOz0tpWfpWIcHUF8N/K
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mzKLN5zBbZA2hi/keDi9PiHi+eLSksju8jS3DyEC2Ufcl0AWlBPl7mr6uJd356Nq5E=
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mw7Iyfe+th+9ZQrXuXywp3bKzVH7FftePdKWEhNC37kwBxi60Dl4seD
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mzNZ8szBTxcuZNDxZgveEmBCETdAstkPohVWDDfTA712w==
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+my5EL++kfvBCf3TEDj6MFK/GA6eXw6ssQ54rS77O4UNo2cjRoJcfkSJ
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mx8fHJXWPDvl/HuprUCpPDGMkBe7k4w/PE0m/PbBYzaQCDGHj5BSZT2D9bcfg6PpJAUD7zu2VlbMOLUxDgzouCE8apk8AB09mNbNssKlIIP0Q==
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mxFVKwck3qUMACA/xw17ozvbKvTJaHguSs=
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mxltwwCKEc2GUG5YGpzwMxRlXulUSEi8FmJ4KbyK6zRhd1S2U3W2mg1X59g8pa2K6GoEOpXVylhPX5Ht9xMlpFD
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+myaTuRoahl4rXcvgzAxNmhq0b73CKwSqJaFtO33qmLurQ==
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mwOWyy56s4dLxyVp5sB6C7hvOPf7HWd2hQL7xI1Nd92MDPwEqv4EctoxLzBdnLgDyNP2ARpZ1j29w==
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mws7JEiVZSPEiuwqo6mZFVz9JUwr1mxDufrDDCLwLaKlN3EHsb6pYdqLdBWPYssiiCVmLQIVIrRIOh6R8Z8LUILSi7PTjWb/fzw8GxlA0wuavbMerEw6cZI
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+myRBd9+JtWYNFvEpSZpTAtDEEbiJVKe1Li+vxLoF16lbeLFsvYvF40TZFokvBCV5LI=
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mzv0/Bp7Uop3Qagee35jc77wDMyXG64tt4ekEoaeslO5CkQd54fR+6SA4K9QKfjx6x9oEvvk0OMJwfgq7BFYmbl9x5YJSwJu+Y=
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mzL38bQMNHr0PR+TUiGNuuXVruP/k9qn4FbA/fs4qg6YfAnMVPAOvGulsC1UETDZPAhyvt08bPrm0173/bbBue5
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+my5IqNrKagoxSkBZxeSxYDC9SuGcAIiGRN5QCWkcpM7og==
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mw3hBbkM5oktPTz4N40w5ZDXFUwYrvRnVsvC0FIFKlrHdPEZjYuWHUrAFaAPYtkHYXZDaJyuxaYXw==
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+myaV7JggXbrBb35/dtDujwqndyVjYVvJBJk0D7TtZEic6F3hM6m0gGmqZw3ZVu4DqQ=
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mwfJk0vH+ekVhDQZF9xIL3/Fs4wqkVF9W3srcioCHo7r4zuU0eU+FjSKbnquWV2Dzchu87SBmZEBA==
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mwiej9iRiYjsb9RYxgGqTb1hZ/HUyvKUr2uFubuKNXW6Lvv8a5rQ3KpnQyAsRfNOmJ8xH7pPpm8SXNUtWutIiZk
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mzFpdzNxCZ7BLKJfQI0zMY0tqXMcUHL662hthHJV/NcthZjMRuYx8/O1dCq3ZLy73YnfXIGA/F+nItw8+OBL59M
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mz4XVeVCtSnhohBPFjc0hQpxryTZNEyl5zKfCNLiG2NMKRkWhfsZH0e
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mw5vNWSrJOvc9F59rG74H0DuzT1j9Uex3zGdH8dB0II09xFt5tpfDAHMVPaNKKbPWRHX8yc3fFcZpBJZ5ofI4YA
#   Fetching HTML: https://jansoochna.rajasthan.gov.in/Services?q=l7aag+q8+mzZLy7GBPF57RSpZMQOYV0UrSCylQJRF7Uf7G2rfsmMYSiyJ4sycTXkn/Q6eEL5hKI=
# Found 73 unique PDF links for Rajasthan.
# Downloading Rajasthan PDFs:   0%|          | 0/20 [00:00<?, ?it/s]
#   Fetching PDF: https://jankalyanfile.rajasthan.gov.in//Content/UploadFolder/OrderEntry/Gopalan/2020/Annual%20Progress%20Report/O_200820_36f621e4-27cc-4abc-aaae-a4873200163e.pdf
#   -> Error processing PDF https://jankalyanfile.rajasthan.gov.in//Content/UploadFolder/OrderEntry/Gopalan/2020/Annual%20Progress%20Report/O_200820_36f621e4-27cc-4abc-aaae-a4873200163e.pdf: download_and_extract_pdf() missing 1 required positional argument: 'session'
#   Fetching PDF: https://jankalyanfile.rajasthan.gov.in//Content/UploadFolder/OrderEntry/Gopalan/2020/Annual%20Progress%20Report/O_200820_03eae4e9-a205-4758-80c4-c92f498bc688.pdf
#   -> Error processing PDF https://jankalyanfile.rajasthan.gov.in//Content/UploadFolder/OrderEntry/Gopalan/2020/Annual%20Progress%20Report/O_200820_03eae4e9-a205-4758-80c4-c92f498bc688.pdf: download_and_extract_pdf() missing 1 required positional argument: 'session'
#   Fetching PDF: http://rmsc.health.rajasthan.gov.in/content/dam/doitassets/Medical-and-Health-Portal/national-ayush-mission/pdf/OperationalGuideline/Bye%20Laws.pdf
#   -> Error processing PDF http://rmsc.health.rajasthan.gov.in/content/dam/doitassets/Medical-and-Health-Portal/national-ayush-mission/pdf/OperationalGuideline/Bye%20Laws.pdf: download_and_extract_pdf() missing 1 required positional argument: 'session'
#   Fetching PDF: https://forest.rajasthan.gov.in/content/dam/raj/forest/ForestDepartment/PDFs/Department%20Wing/N.T.F.P/Tendu%20patta%20dt.%2013.08.2020.pdf
#   -> Error processing PDF https://forest.rajasthan.gov.in/content/dam/raj/forest/ForestDepartment/PDFs/Department%20Wing/N.T.F.P/Tendu%20patta%20dt.%2013.08.2020.pdf: download_and_extract_pdf() missing 1 required positional argument: 'session'
#   Fetching PDF: https://jankalyanfile.rajasthan.gov.in//Content/UploadFolder/OrderEntry/KHA_/2023/Publication/O_030223_94bcd448-2ce2-4388-be7d-ff3fd73d4461.pdf
#   -> Error processing PDF https://jankalyanfile.rajasthan.gov.in//Content/UploadFolder/OrderEntry/KHA_/2023/Publication/O_030223_94bcd448-2ce2-4388-be7d-ff3fd73d4461.pdf: download_and_extract_pdf() missing 1 required positional argument: 'session'
#   Fetching PDF: https://jankalyanfile.rajasthan.gov.in/Content/UploadFolder/OrderEntry/IND_DMIC/2023/Annual_Progress_Report/O_240123_d74c0210-6753-4cee-ada9-f1a4504a0373.pdf
#   -> Error processing PDF https://jankalyanfile.rajasthan.gov.in/Content/UploadFolder/OrderEntry/IND_DMIC/2023/Annual_Progress_Report/O_240123_d74c0210-6753-4cee-ada9-f1a4504a0373.pdf: download_and_extract_pdf() missing 1 required positional argument: 'session'
#   Fetching PDF: https://jankalyanfile.rajasthan.gov.in/Content/UploadFolder/OrderEntry/IND%20DMIC/2021/Act%20_%20Rules/O_180221_1b8934e5-67f9-4584-bd3a-6d38d2f4c4d6.pdf
#   -> Error processing PDF https://jankalyanfile.rajasthan.gov.in/Content/UploadFolder/OrderEntry/IND%20DMIC/2021/Act%20_%20Rules/O_180221_1b8934e5-67f9-4584-bd3a-6d38d2f4c4d6.pdf: download_and_extract_pdf() missing 1 required positional argument: 'session'
#   Fetching PDF: https://jankalyanfile.rajasthan.gov.in//Content/UploadFolder/OrderEntry/Gopalan/2022/Publication/O_130322_6621534d-c00c-438b-9b34-9c525f0d9cb0.pdf
#   -> Error processing PDF https://jankalyanfile.rajasthan.gov.in//Content/UploadFolder/OrderEntry/Gopalan/2022/Publication/O_130322_6621534d-c00c-438b-9b34-9c525f0d9cb0.pdf: download_and_extract_pdf() missing 1 required positional argument: 'session'
#   Fetching PDF: http://rtdc.tourism.rajasthan.gov.in/Pdf/Pages_StudentPackage.pdf
#   -> Error processing PDF http://rtdc.tourism.rajasthan.gov.in/Pdf/Pages_StudentPackage.pdf: download_and_extract_pdf() missing 1 required positional argument: 'session'
#   Fetching PDF: https://jankalyanfile.rajasthan.gov.in//Content/UploadFolder/OrderEntry/Gopalan/2020/Publication/O_200820_f11354bd-98f5-4cb0-8754-159c25f69f35.pdf
#   -> Error processing PDF https://jankalyanfile.rajasthan.gov.in//Content/UploadFolder/OrderEntry/Gopalan/2020/Publication/O_200820_f11354bd-98f5-4cb0-8754-159c25f69f35.pdf: download_and_extract_pdf() missing 1 required positional argument: 'session'
#   Fetching PDF: http://transport.rajasthan.gov.in/content/dam/transport/jaipurbus/image/Concession%20Order%2016-07-2018.pdf
#   -> Error processing PDF http://transport.rajasthan.gov.in/content/dam/transport/jaipurbus/image/Concession%20Order%2016-07-2018.pdf: download_and_extract_pdf() missing 1 required positional argument: 'session'
#   Fetching PDF: https://jankalyanfile.rajasthan.gov.in//Content/UploadFolder/OrderEntry/Gopalan/2022/Publication/O_130322_ee25007c-b985-4167-a118-dbd5016b5f26.pdf
#   -> Error processing PDF https://jankalyanfile.rajasthan.gov.in//Content/UploadFolder/OrderEntry/Gopalan/2022/Publication/O_130322_ee25007c-b985-4167-a118-dbd5016b5f26.pdf: download_and_extract_pdf() missing 1 required positional argument: 'session'
#   Fetching PDF: http://law.rajasthan.gov.in/content/dam/law-justice/Law%20%26%20Legal%20Affairs%20Department/PDF/ActsRules/RLAM(POD)Act%252c20170001.pdf
#   -> Error processing PDF http://law.rajasthan.gov.in/content/dam/law-justice/Law%20%26%20Legal%20Affairs%20Department/PDF/ActsRules/RLAM(POD)Act%252c20170001.pdf: download_and_extract_pdf() missing 1 required positional argument: 'session'
#   Fetching PDF: https://jankalyanfile.rajasthan.gov.in//Content/UploadFolder/OrderEntry/Gopalan/2020/Publication/O_200820_dfa7f91c-53a5-4800-aa91-2adc6be44990.pdf
#   -> Error processing PDF https://jankalyanfile.rajasthan.gov.in//Content/UploadFolder/OrderEntry/Gopalan/2020/Publication/O_200820_dfa7f91c-53a5-4800-aa91-2adc6be44990.pdf: download_and_extract_pdf() missing 1 required positional argument: 'session'
#   Fetching PDF: https://jankalyanfile.rajasthan.gov.in//Content/UploadFolder/OrderEntry/Gopalan/2023/Annual_Progress_Report/O_170123_e98f68d2-8cb0-4c65-9396-76e64bf0857f.pdf
#   -> Error processing PDF https://jankalyanfile.rajasthan.gov.in//Content/UploadFolder/OrderEntry/Gopalan/2023/Annual_Progress_Report/O_170123_e98f68d2-8cb0-4c65-9396-76e64bf0857f.pdf: download_and_extract_pdf() missing 1 required positional argument: 'session'
#   Fetching PDF: https://home.rajasthan.gov.in/content/dam/HomeGuardsfile/Currentnews/Rules%20In%20Hindi.pdf
#   -> Error processing PDF https://home.rajasthan.gov.in/content/dam/HomeGuardsfile/Currentnews/Rules%20In%20Hindi.pdf: download_and_extract_pdf() missing 1 required positional argument: 'session'
#   Fetching PDF: http://rsacs.in/media/RTI.pdf
#   -> Error processing PDF http://rsacs.in/media/RTI.pdf: download_and_extract_pdf() missing 1 required positional argument: 'session'
#   Fetching PDF: https://devasthan.rajasthan.gov.in/Files/Moksh_Kalash_Yojna.pdf
#   -> Error processing PDF https://devasthan.rajasthan.gov.in/Files/Moksh_Kalash_Yojna.pdf: download_and_extract_pdf() missing 1 required positional argument: 'session'
#   Fetching PDF: http://rtdc.tourism.rajasthan.gov.in/Pdf/SpecialOffers.pdf
#   -> Error processing PDF http://rtdc.tourism.rajasthan.gov.in/Pdf/SpecialOffers.pdf: download_and_extract_pdf() missing 1 required positional argument: 'session'
#   Fetching PDF: https://minority.rajasthan.gov.in/WAQF-Board/upload/THEWAQFACT1995.pdf
#   -> Error processing PDF https://minority.rajasthan.gov.in/WAQF-Board/upload/THEWAQFACT1995.pdf: download_and_extract_pdf() missing 1 required positional argument: 'session'
# \n--- Processing AndhraPradesh ---
# Crawling housing.ap.gov.in:   0%|          | 0/150 [00:00<?, ?it/s]
# Found 0 candidate pages for AndhraPradesh.
# No candidate links found for AndhraPradesh, moving to the next one.
# \n--- Processing Telangana ---
# Crawling www.telangana.gov.in:   0%|          | 0/150 [00:00<?, ?it/s]
# Found 0 candidate pages for Telangana.
# No candidate links found for Telangana, moving to the next one.
# \n--- Processing Bihar ---
# Crawling dbt.bihar.gov.in:   0%|          | 0/150 [00:00<?, ?it/s]
# Found 4 candidate pages for Bihar.
# Scraping Bihar HTMLs:   0%|          | 0/4 [00:00<?, ?it/s]
#   Fetching HTML: https://dbt.bihar.gov.in/wp/SchemeList.aspx
#   Fetching HTML: https://dbt.bihar.gov.in/wp/DepartmentSchemeWiseReport.aspx
#   Fetching HTML: https://dbt.bihar.gov.in/wp/LastUpdate_Scheme.aspx
#   Fetching HTML: https://dbt.bihar.gov.in/wp/DepartmentList.aspx
# Found 0 unique PDF links for Bihar.
# Downloading Bihar PDFs: 0it [00:00, ?it/s]
# \n--- Processing Odisha ---
# Crawling rd.odisha.gov.in:   0%|          | 0/150 [00:00<?, ?it/s]
# Found 31 candidate pages for Odisha.
# Scraping Odisha HTMLs:   0%|          | 0/31 [00:00<?, ?it/s]
#   Fetching HTML: https://rd.odisha.gov.in/quicktabs/nojs/rural_department_organisation_ch/0
#   -> Timeout error on URL: https://rd.odisha.gov.in/quicktabs/nojs/rural_department_organisation_ch/0
#   Fetching HTML: https://rd.odisha.gov.in/scheme/mmsy-cuvda
#   -> Timeout error on URL: https://rd.odisha.gov.in/scheme/mmsy-cuvda
#   Fetching HTML: https://rd.odisha.gov.in/or/about-us/about-department
#   -> Timeout error on URL: https://rd.odisha.gov.in/or/about-us/about-department
#   Fetching HTML: https://rd.odisha.gov.in/scheme/sby
#   -> Timeout error on URL: https://rd.odisha.gov.in/scheme/sby
#   Fetching HTML: https://rd.odisha.gov.in/or/guidelines
#   -> Timeout error on URL: https://rd.odisha.gov.in/or/guidelines
#   Fetching HTML: https://rd.odisha.gov.in/departmentwise-citizen-services-list
#   -> Timeout error on URL: https://rd.odisha.gov.in/departmentwise-citizen-services-list
#   Fetching HTML: https://rd.odisha.gov.in/or/scheme
#   -> Timeout error on URL: https://rd.odisha.gov.in/or/scheme
#   Fetching HTML: https://rd.odisha.gov.in/sites/default/files/2020-01/Programme-guidelines-pmgsy-iii-1_compressed.pdf
#   -> Timeout error on URL: https://rd.odisha.gov.in/sites/default/files/2020-01/Programme-guidelines-pmgsy-iii-1_compressed.pdf
#   Fetching HTML: https://rd.odisha.gov.in/scheme/bridge-cum-weir
#   -> Timeout error on URL: https://rd.odisha.gov.in/scheme/bridge-cum-weir
#   Fetching HTML: https://rd.odisha.gov.in/about-us/organogram
#   -> Timeout error on URL: https://rd.odisha.gov.in/about-us/organogram
#   Fetching HTML: https://rd.odisha.gov.in/quicktabs/nojs/rural_department_organisation_ch/1
#   -> Timeout error on URL: https://rd.odisha.gov.in/quicktabs/nojs/rural_department_organisation_ch/1
#   Fetching HTML: https://rd.odisha.gov.in/scheme/ridf
#   -> Timeout error on URL: https://rd.odisha.gov.in/scheme/ridf
#   Fetching HTML: https://rd.odisha.gov.in/scheme
#   -> Timeout error on URL: https://rd.odisha.gov.in/scheme
#   Fetching HTML: https://rd.odisha.gov.in/or/about-us/organogram
#   -> Timeout error on URL: https://rd.odisha.gov.in/or/about-us/organogram
#   Fetching HTML: https://rd.odisha.gov.in/scheme/pmgsy
#   -> Timeout error on URL: https://rd.odisha.gov.in/scheme/pmgsy
#   Fetching HTML: https://rd.odisha.gov.in/or/notification/circulars
#   -> Timeout error on URL: https://rd.odisha.gov.in/or/notification/circulars
#   Fetching HTML: https://rd.odisha.gov.in/sites/default/files/2020-04/PROGRAMME-GUIDELINES-PMGSY-III-1.pdf
#   -> Timeout error on URL: https://rd.odisha.gov.in/sites/default/files/2020-04/PROGRAMME-GUIDELINES-PMGSY-III-1.pdf
#   Fetching HTML: https://rd.odisha.gov.in/
#   -> Timeout error on URL: https://rd.odisha.gov.in/
#   Fetching HTML: https://rd.odisha.gov.in/about-us/about-department
#   -> Timeout error on URL: https://rd.odisha.gov.in/about-us/about-department
#   Fetching HTML: https://rd.odisha.gov.in/notification/eoi
#   -> Timeout error on URL: https://rd.odisha.gov.in/notification/eoi
#   Fetching HTML: https://rd.odisha.gov.in/notifications/office-order
#   -> Timeout error on URL: https://rd.odisha.gov.in/notifications/office-order
#   Fetching HTML: https://rd.odisha.gov.in/scheme/rltap
#   -> Timeout error on URL: https://rd.odisha.gov.in/scheme/rltap
#   Fetching HTML: https://rd.odisha.gov.in/notification/circulars
#   -> Timeout error on URL: https://rd.odisha.gov.in/notification/circulars
#   Fetching HTML: https://rd.odisha.gov.in/scheme/mmsy-cmrl
#   -> Timeout error on URL: https://rd.odisha.gov.in/scheme/mmsy-cmrl
#   Fetching HTML: https://rd.odisha.gov.in/quicktabs/nojs/social_feeds_social_media/1
#   -> Timeout error on URL: https://rd.odisha.gov.in/quicktabs/nojs/social_feeds_social_media/1
#   Fetching HTML: https://rd.odisha.gov.in/scheme/mmsy
#   -> Timeout error on URL: https://rd.odisha.gov.in/scheme/mmsy
#   Fetching HTML: https://rd.odisha.gov.in/or/notifications/office-order
#   -> Timeout error on URL: https://rd.odisha.gov.in/or/notifications/office-order
#   Fetching HTML: https://rd.odisha.gov.in/guidelines
#   -> Timeout error on URL: https://rd.odisha.gov.in/guidelines
#   Fetching HTML: https://rd.odisha.gov.in/scheme/ombadc
#   -> Timeout error on URL: https://rd.odisha.gov.in/scheme/ombadc
#   Fetching HTML: https://rd.odisha.gov.in/sites/default/files/2025-04/PMGSY-IV%20Final%20Guidelines.pdf
#   -> Timeout error on URL: https://rd.odisha.gov.in/sites/default/files/2025-04/PMGSY-IV%20Final%20Guidelines.pdf
#   Fetching HTML: https://rd.odisha.gov.in/scheme/cwa
#   -> Timeout error on URL: https://rd.odisha.gov.in/scheme/cwa
# Found 0 unique PDF links for Odisha.
# Downloading Odisha PDFs: 0it [00:00, ?it/s]
# \nFinished processing all states. Total documents extracted: 221

# %% [markdown]
# Cell 8 — Phase 3: preprocessing & chunking

# %% [markdown]
# Cell 9 — Phase 4: embeddings + vector store (sentence-transformers + sklearn NN)

# %%
# Colab cell 9 (Corrected) - model init and indexing chunks from all_documents
from sentence_transformers import SentenceTransformer
import numpy as np
from sklearn.neighbors import NearestNeighbors

# This assumes model is loaded, if not, uncomment the line below
model = SentenceTransformer('all-MiniLM-L6-v2')

# Gather chunks from the single, consolidated 'all_documents' list
corpus_chunks = []
metadata = []

for doc in tqdm(all_documents, desc="Chunking all documents"):
    content = doc.get("content", "")
    if not content:
        continue

    chunks = chunk_text(content)
    for i, chunk in enumerate(chunks):
        corpus_chunks.append(chunk)
        # Add rich metadata for each chunk
        metadata.append({
            "state": doc["state"],
            "source_url": doc["source_url"],
            "scheme_title": doc["title"],
            "type": doc["type"],
            "chunk_num": i + 1
        })

print(f"Total chunks to be indexed: {len(corpus_chunks)}")

if not corpus_chunks:
    print("No chunks to embed — the crawl might not have found any content.")
else:
    embeddings = model.encode(corpus_chunks, show_progress_bar=True, convert_to_numpy=True)

    # This is your vector store.
    vector_store = {
        "embeddings": embeddings,
        "metadata": metadata,
        "chunks": corpus_chunks
    }

    # Build the nearest-neighbor index for fast retrieval
    nn_index = NearestNeighbors(n_neighbors=5, metric='cosine').fit(vector_store["embeddings"])

    print("Vector database and NearestNeighbors index are ready.")
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Chunking all documents:   0%|          | 0/221 [00:00<?, ?it/s]
# Total chunks to be indexed: 3332
# Batches:   0%|          | 0/105 [00:00<?, ?it/s]
# Vector database and NearestNeighbors index are ready.

# %%
# NEW CELL: Save the Vector Database, Index, and Model to disk

import pickle

print("Saving the vector database and index to files...")

# 1. Save the vector_store dictionary
with open("vector_store.pkl", "wb") as f:
    pickle.dump(vector_store, f)

# 2. Save the NearestNeighbors index object
with open("nn_index.pkl", "wb") as f:
    pickle.dump(nn_index, f)

# 3. Save the model itself
# The sentence-transformer library has a built-in save method
model.save("my_embedding_model")

print("Successfully saved:")
print("- vector_store.pkl (your data and embeddings)")
print("- nn_index.pkl (the search index)")
print("- my_embedding_model/ (the AI model)")
# Out:
# Saving the vector database and index to files...
# Successfully saved:
# - vector_store.pkl (your data and embeddings)
# - nn_index.pkl (the search index)
# - my_embedding_model/ (the AI model)

# %% [markdown]
# ## Starting

# %%
# to load and run model from here

# NEW CELL: Load the saved database, index, and model from disk

import pickle
from sentence_transformers import SentenceTransformer
from sklearn.neighbors import NearestNeighbors

print("Loading vector database, index, and model from files...")

# 1. Load the vector_store
with open("vector_store.pkl", "rb") as f:
    vector_store = pickle.load(f)

# 2. Load the nn_index
with open("nn_index.pkl", "rb") as f:
    nn_index = pickle.load(f)

# 3. Load the SentenceTransformer model
model = SentenceTransformer("my_embedding_model")

# You can now access the data just like before
print(f"Successfully loaded. The database contains {len(vector_store['chunks'])} chunks.")

# Verify that the rest of the notebook works
print("\\nRunning a test query to confirm everything is loaded correctly...")
test_query = "scholarship for students"
test_results = retrieve(test_query, top_k=2)
for r in test_results:
    print(f"- Found chunk from: {r['meta']['source_url']}")

# %% [markdown]
# Cell 10 — Phase 4b: simple RAG-style retrieval + extractive summary

# %%
# Colab cell 10 - query the vector store and produce an extractive summary
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer

def retrieve(query, top_k=4):
    qv = model.encode([query])
    dists, idxs = nn_index.kneighbors(qv, n_neighbors=top_k)
    res = []
    for i in idxs[0]:
        res.append({"chunk":corpus_chunks[i], "meta": metadata[i]})
    return res

def extractive_summary_from_chunks(chunks, n_sent=6):
    # naive extractive: combine chunks and select top tf-idf sentences
    bigtext = " ".join(chunks)
    sents = sent_tokenize(bigtext)
    if len(sents)<=n_sent:
        return bigtext
    vect = TfidfVectorizer().fit_transform(sents)
    scores = np.array(vect.sum(axis=1)).ravel()
    top_idx = scores.argsort()[::-1][:n_sent]
    top_idx_sorted = sorted(top_idx)
    return " ".join([sents[i] for i in top_idx_sorted])

# demo query
q = "scholarship amount eligibility"
results = retrieve(q, top_k=5)
print("Top context snippets:")
for r in results:
    print("-", r["meta"].get("source",""), " len:", len(r["chunk"]))
summary = extractive_summary_from_chunks([r["chunk"] for r in results], n_sent=5)
print("\nExtractive summary:\n", summary[:800])
# Out:
# Top context snippets:
# -   len: 1270
# -   len: 1294
# -   len: 1469
# -   len: 1455
# -   len: 1448
#
# Extractive summary:
#  5) If Applicant fails in particular year then he will get the Tuition Fees, Exam Fees and Maintenance allowance of that particular academic year but he/she will not get the benefit until he/she gets promoted to next higher class. 6) If Applicant fails in particular year then he will get the Tuition Fees, Exam Fees and Maintenance allowance of that particular academic year but he/she will not get the benefit until he/she gets promoted to next higher class. Guidelines On “'Right to Give Up'” Guidelines and Rules Download Colleges list Right To Give Up GR Guidelines for SEBC Eligibility Click here for Help Help Videos × DBT overview × Registration with UID × Login and Logout Process × User Profile Update Process × Apply Schemes Process × DBT Grievance and Suggestions Merit Scholarships for Ec

# %% [markdown]
# Cell 11 — Phase 4c: Generate a Markdown "wiki" page from retrieved content

# %%
# Colab cell 11 - produce a simple wiki/markdown page for a scheme
def make_wiki_md(title, retrieved_chunks, source_urls):
    summary = extractive_summary_from_chunks([c for c in retrieved_chunks], n_sent=6)
    md = f"# {title}\n\n"
    md += "## Summary\n\n" + summary + "\n\n"
    md += "## Sources\n"
    for u in source_urls:
        md += f"- {u}\n"
    return md

# demo: title from query
title = "Auto-generated Scheme summary — demo"
md = make_wiki_md(title, [r["chunk"] for r in results], list({r["meta"].get("source") for r in results}))
with open("wiki_pages/demo_scheme.md","w",encoding="utf-8") as f:
    f.write(md)
print("Saved wiki markdown:", "wiki_pages/demo_scheme.md")
print(md[:800])
# Out:
# Saved wiki markdown: wiki_pages/demo_scheme.md
# # Auto-generated Scheme summary — demo
#
# ## Summary
#
# 5) If Applicant fails in particular year then he will get the Tuition Fees, Exam Fees and Maintenance allowance of that particular academic year but he/she will not get the benefit until he/she gets promoted to next higher class. 6) If Applicant fails in particular year then he will get the Tuition Fees, Exam Fees and Maintenance allowance of that particular academic year but he/she will not get the benefit until he/she gets promoted to next higher class. Guidelines On “'Right to Give Up'” Guidelines and Rules Download Colleges list Right To Give Up GR Guidelines for SEBC Eligibility Click here for Help Help Videos × DBT overview × Registration with UID × Login and Logout Process × User Profile Update Process × Apply Schemes Process × DBT

# %%
# FINAL VERSION FOR CELL 9: Load Model, Build Vector DB, and Save Everything

from sentence_transformers import SentenceTransformer
import numpy as np
from sklearn.neighbors import NearestNeighbors
import pickle

# --- 1. Load the AI Model ---
# This is fast if it has been downloaded before.
print("Loading the Sentence Transformer model...")
try:
    # Check if a local copy exists to load faster
    model = SentenceTransformer("./my_embedding_model")
    print("Loaded model from local files.")
except Exception:
    model = SentenceTransformer('all-MiniLM-L6-v2')
    print("Downloaded and loaded new model instance.")


# --- 2. Gather Chunks from the NEW 'all_documents' list ---
# This step uses the fresh data from your complete crawl.
corpus_chunks = []
metadata = []

if 'all_documents' not in globals() or not all_documents:
    print("Error: 'all_documents' is empty. Please run the main crawling cell first.")
else:
    for doc in tqdm(all_documents, desc="Chunking all documents"):
        content = doc.get("content", "")
        if not content: continue

        chunks = chunk_text(content)
        for i, chunk in enumerate(chunks):
            corpus_chunks.append(chunk)
            metadata.append({
                "state": doc["state"],
                "source_url": doc["source_url"],
                "scheme_title": doc["title"],
                "type": doc["type"],
                "chunk_num": i + 1
            })

print(f"Total chunks to be indexed from all states: {len(corpus_chunks)}")


# --- 3. Create NEW Embeddings and Build the Index ---
if not corpus_chunks:
    print("No chunks to embed. Cannot build or save the vector database.")
else:
    print("Creating new embeddings for the complete dataset... (This may take some time)")
    embeddings = model.encode(corpus_chunks, show_progress_bar=True, convert_to_numpy=True)

    vector_store = {
        "embeddings": embeddings,
        "metadata": metadata,
        "chunks": corpus_chunks
    }

    nn_index = NearestNeighbors(n_neighbors=5, metric='cosine').fit(vector_store["embeddings"])

    print("New vector database and index are ready.")

    # --- 4. OVERWRITE Old Saved Files with the New, Complete Versions ---
    print("Saving the new, complete vector database and index to files...")

    with open("vector_store.pkl", "wb") as f:
        pickle.dump(vector_store, f)

    with open("nn_index.pkl", "wb") as f:
        pickle.dump(nn_index, f)

    model.save("my_embedding_model")

    print("Successfully updated and saved all database files.")
# Out:
# Loading the Sentence Transformer model...
# Loaded model from local files.
# Chunking all documents:   0%|          | 0/221 [00:00<?, ?it/s]
# Total chunks to be indexed from all states: 3332
# Creating new embeddings for the complete dataset... (This may take some time)
# Batches:   0%|          | 0/105 [00:00<?, ?it/s]
# New vector database and index are ready.
# Saving the new, complete vector database and index to files...
# Successfully updated and saved all database files.

# %% [markdown]
# Cell 12 — Phase 5: Simple publish — local Flask app + ngrok to serve generated wiki pages (and embed official site links)

# %%
# COMPLETE CODE FOR WIKI GENERATION

print("Generating state-wise wiki pages from the scraped content...")

# Ensure the output directory exists
ensure_dir("state_wikis")

# Check if the source data exists before starting
if 'all_documents' not in globals() or not all_documents:
    print("Error: The 'all_documents' list is empty. Please run the main crawling and extraction cell first.")
else:
    # Loop through each state defined in your 'seeds' dictionary
    for state in seeds.keys():

        # Filter to get all documents scraped for the current state
        state_docs = [doc for doc in all_documents if doc.get('state') == state]

        # If no documents were found for this state, skip it
        if not state_docs:
            print(f"- No content found for {state}. Skipping wiki generation.")
            continue

        # Start building the Markdown string for this state's wiki page
        md_content = f"# Government Schemes and Information for {state}\\n\\n"
        md_content += "This document is an auto-generated compilation of information scraped from official government portals.\\n\\n---\\n\\n"

        # Loop through each document (HTML page or PDF) for the state
        for doc in state_docs:
            # Add a section for this document
            md_content += f"## {doc.get('title', 'Untitled Document')}\\n\\n"
            md_content += f"**Source Type:** `{doc.get('type', 'N/A')}`\\n"
            md_content += f"**Source URL:** <{doc.get('source_url', '#')}>\\n\\n"
            md_content += "### Extracted Content\\n"
            # Add the cleaned content, ensuring it's not empty
            md_content += f"{doc.get('content', 'No content was extracted.')}\\n\\n---\\n\\n"

        # Define the output filename
        wiki_filename = f"state_wikis/{state}_schemes.md"

        # Write the compiled Markdown content to a file
        try:
            with open(wiki_filename, "w", encoding="utf-8") as f:
                f.write(md_content)
            print(f"✔ Successfully created wiki for {state} at: {wiki_filename}")
        except Exception as e:
            print(f"✘ Failed to write wiki file for {state}. Error: {e}")

print("\nWiki page generation process complete.")
# Out:
# Generating state-wise wiki pages from the scraped content...
# ✔ Successfully created wiki for Maharashtra at: state_wikis/Maharashtra_schemes.md
# ✔ Successfully created wiki for UttarPradesh at: state_wikis/UttarPradesh_schemes.md
# - No content found for TamilNadu. Skipping wiki generation.
# - No content found for Karnataka. Skipping wiki generation.
# - No content found for Gujarat. Skipping wiki generation.
# - No content found for WestBengal. Skipping wiki generation.
# - No content found for JammuKashmir. Skipping wiki generation.
# ✔ Successfully created wiki for Rajasthan at: state_wikis/Rajasthan_schemes.md
# - No content found for AndhraPradesh. Skipping wiki generation.
# - No content found for Telangana. Skipping wiki generation.
# ✔ Successfully created wiki for Bihar at: state_wikis/Bihar_schemes.md
# - No content found for Odisha. Skipping wiki generation.
#
# Wiki page generation process complete.

# %%
# Colab Cell 12 (Corrected) - Flask server with ngrok

# !pip install -q pyngrok

from flask import Flask, send_from_directory, render_template_string
from pyngrok import ngrok
import os

# 🔑 Your ngrok authtoken setup
# !ngrok config add-authtoken 33Mekt30HdxOkZuN1c2KWUYTGUF_6pGi4PxV4HvFopXqgEhKA

app = Flask(__name__)

# MODIFIED: Template now points to the correct wiki files
CARD_TPL = """
<!doctype html><html><head><title>Gov Schemes Wiki</title>
<style> body { font-family: sans-serif; } .card { border:1px solid #ddd;padding:12px;margin:8px;border-radius:8px;} .grid{display:grid;grid-template-columns:repeat(auto-fill, minmax(350px, 1fr));gap:12px;} a { color: #007bff; text-decoration: none; } a:hover { text-decoration: underline; }</style></head><body>
<h1>Government Schemes Knowledge Base</h1>
<div class="grid">
{% for s,u in seeds.items() %}
  <div class="card">
    <h3>{{s}}</h3>
    <p><b><a href="{{u}}" target="_blank">Official Portal &rarr;</a></b></p>
    {% set wiki_file = s + "_schemes.md" %}
    {% if os.path.exists("state_wikis/" + wiki_file) %}
      <p><a href="/wiki/{{wiki_file}}">View Generated Wiki Page</a></p>
    {% else %}
      <p><em>No wiki file generated for this state.</em></p>
    {% endif %}
  </div>
{% endfor %}
</div>
</body></html>
"""

@app.route("/")
def index():
    return render_template_string(CARD_TPL, seeds=seeds, os=os)

# MODIFIED: Route now serves from the 'state_wikis' directory
@app.route("/wiki/<path:fn>")
def wiki_file(fn):
    path = os.path.join(os.getcwd(), "state_wikis") # <-- Corrected directory
    if os.path.exists(os.path.join(path, fn)):
        return send_from_directory(path, fn)
    else:
        return "Wiki file not found.", 404

# Open a public ngrok tunnel
port = 5000
public_url = ngrok.connect(port).public_url
print(f"🚀 Your public web app is live at: {public_url}")

# Run the Flask app
app.run(port=port)
# Out:
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml
# 🚀 Your public web app is live at: https://rose-nonelaborate-alexandria.ngrok-free.dev
#  * Serving Flask app '__main__'
#  * Debug mode: off
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# INFO:werkzeug:Press CTRL+C to quit
# INFO:werkzeug:127.0.0.1 - - [03/Oct/2025 06:49:31] "GET / HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [03/Oct/2025 06:49:35] "GET /wiki/Maharashtra_schemes.md HTTP/1.1" 200 -

# %% [markdown]
# Cell 13 — Phase 6: change detection + versioning (SQLite)

# %%
# Colab cell 13 (Corrected) - compute content hash and store diffs

# ... (database setup code is correct) ...
conn = sqlite3.connect("versions.db")
c = conn.cursor()
c.execute("""CREATE TABLE IF NOT EXISTS versions (
    id INTEGER PRIMARY KEY,
    source_url TEXT,
    content_hash TEXT,
    snippet TEXT,
    timestamp DATETIME DEFAULT CURRENT_TIMESTAMP
)""")
conn.commit()

def store_version(source_url, text_snippet):
    h = hashlib.sha256(text_snippet.encode("utf-8")).hexdigest()
    c.execute("SELECT content_hash FROM versions WHERE source_url=? ORDER BY id DESC LIMIT 1",(source_url,))
    row = c.fetchone()
    if row and row[0]==h:
        return False
    c.execute("INSERT INTO versions (source_url, content_hash, snippet) VALUES (?,?,?)",(source_url,h,text_snippet[:2000]))
    conn.commit()
    return True

# MODIFIED: Test store using the correct 'all_documents' variable
print("Checking for new/changed content to store in version database...")
changes_found = 0
for p in all_documents:
    changed = store_version(p["source_url"], p["content"])
    if changed:
        changes_found += 1
        print(f"  -> Stored new version for: {p['source_url']}")
print(f"Finished. Found and stored {changes_found} new document versions.")

# %% [markdown]
# Cell 14 — Phase 7: schedule periodic crawling (APScheduler)

# %%
# Colab cell 14 (Corrected) - schedule a periodic job
from apscheduler.schedulers.background import BackgroundScheduler
import atexit

scheduler = BackgroundScheduler()
def periodic_job():
    print("\\n--- Running Scheduled Job ---")
    sname, surl = list(seeds.items())[0] # Just checking the first seed as a demo

    # MODIFIED: Using the correct function name 'crawl_with_heuristics'
    links, _ = crawl_with_heuristics(surl, max_pages=20) # Limit pages for a quick check

    print(f"Scheduled check found {len(links)} links on {sname}. You would process these here.")

scheduler.add_job(periodic_job, 'interval', minutes=60)
scheduler.start()
atexit.register(lambda: scheduler.shutdown(wait=False))
print("Scheduler started. It will run a sample check every 60 minutes.")

# %% [markdown]
# Cell 15 — Tests (very small unit test example)

# %%
# Colab cell 15 - basic sanity checks
def test_chunking():
    t = "This is sentence one. Sentence two. Sentence three. Sentence four."
    ch = chunk_text(t, max_chars=30)
    assert len(ch) >= 2
    print("chunking test passed")

test_chunking()

# %% [markdown]
# ## Chatbot Implementation

# %% [markdown]
# Step 1: Full-Scale Crawling and Data Consolidation

# %%
# FINAL CELL: The RAG Chatbot Implementation

import google.generativeai as genai
from google.colab import userdata
import textwrap

# --- Configure the LLM ---
# This safely gets your API key from Colab's secret manager.
try:
    GEMINI_API_KEY = userdata.get('GEMINI_API_KEY')
    genai.configure(api_key=GEMINI_API_KEY)
    llm = genai.GenerativeModel('gemini-pro')
    print("Gemini Pro model configured successfully.")
except Exception as e:
    llm = None
    print(f"Could not configure the LLM. Please follow the instructions to set up your GEMINI_API_KEY. Error: {e}")
# -------------------------

def get_rag_response(query: str, top_k: int = 5):
    """
    Performs the full RAG pipeline: retrieves context, augments prompt, and generates a response.
    """
    if not llm:
        return "LLM is not configured. Cannot generate a response."
    if 'nn_index' not in globals() or 'vector_store' not in globals():
        return "Vector database is not ready. Please ensure the previous cells have been run successfully."

    # 1. RETRIEVE: Find the most relevant chunks from your vector database
    print(f"Retrieving context for query: '{query}'")
    query_embedding = model.encode([query])
    distances, indices = nn_index.kneighbors(query_embedding, n_neighbors=top_k)

    # Consolidate context and gather unique sources for citation
    context_str = ""
    source_citations = {} # Use a dict to store unique URLs with their titles
    for idx in indices[0]:
        context_str += vector_store["chunks"][idx] + "\\n---\\n"
        meta = vector_store["metadata"][idx]
        source_url = meta['source_url']
        if source_url not in source_citations:
            source_citations[source_url] = meta.get('scheme_title', 'Source Link')

    # 2. AUGMENT: Create the prompt for the LLM
    prompt_template = f"""
You are an expert assistant for Indian government schemes. Your task is to answer the user's question based ONLY on the provided context below.
- Be precise and directly answer the question.
- If the context contains eligibility criteria, benefits, or application steps, list them clearly using bullet points.
- If the information to answer the question is not in the context, you MUST state: "Based on the provided information, I cannot answer this question."
- Do not use any information outside of the provided context.

**CONTEXT:**
---
{context_str}
---

**USER'S QUESTION:**
{query}

**ANSWER:**
"""

    # 3. GENERATE: Get the response from the LLM
    print("Generating response with LLM...")
    try:
        response = llm.generate_content(prompt)

        # Format the final output nicely with sources
        final_answer = response.text
        final_answer += "\\n\\n--- \\n"
        final_answer += "**Sources from the Knowledge Base:**\\n"
        for url, title in source_citations.items():
            final_answer += f"- [{title}]({url})\\n"

        return textwrap.fill(final_answer, width=100)

    except Exception as e:
        return f"An error occurred while generating the LLM response: {e}"


# --- Let's test the chatbot! ---
# Make sure all previous cells, including the vector DB creation, have been run.

print("\\n" + "="*50)
print("              RUNNING CHATBOT QUERIES")
print("="*50 + "\\n")


# Query 1: A specific, multi-faceted question
user_query_1 = "Tell me about education scholarships in Maharashtra for students whose parents' income is low."
chatbot_answer_1 = get_rag_response(user_query_1)
print(f"💬 QUERY 1: {user_query_1}")
print(f"🤖 RESPONSE:\\n{chatbot_answer_1}")
print("\\n" + "-"*50 + "\\n")


# Query 2: A different state and domain
user_query_2 = "I am a farmer in Rajasthan. What are the benefits of the Pradhan Mantri Kisan Samman Nidhi scheme?"
chatbot_answer_2 = get_rag_response(user_query_2)
print(f"💬 QUERY 2: {user_query_2}")
print(f"🤖 RESPONSE:\\n{chatbot_answer_2}")
print("\\n" + "-"*50 + "\\n")

# Query 3: A question that may not have context
user_query_3 = "What are the new space exploration grants in Gujarat?"
chatbot_answer_3 = get_rag_response(user_query_3)
print(f"💬 QUERY 3: {user_query_3}")
print(f"🤖 RESPONSE:\\n{chatbot_answer_3}")
